# %% [markdown]
# <a href="https://colab.research.google.com/github/ghousia2123-alt/contact/blob/main/contact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contacts = {
    "Ravi": "9876543210",
    "Sita": "9876501234",
    "Arun": "9123456780",
    "Priya": "9988776655"
}

name = input("Enter contact name to search: ")

if name in contacts:
    print("Phone Number:", contacts[name])
else:
    print("Contact not found")
# Out:
# Enter contact name to search: Priya
# Phone Number: 9988776655
